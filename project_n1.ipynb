# %%
import pip
pip.main(["install","seaborn"])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.50.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
# ...

# %%
# Beginning. Data Analytics for Auditing using pandas.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:/Repo GitHub/Data Analysis/banco.csv")

# %%
df.head()
# Out:
#    ID  prestamo  edad  experiencia  ingreso  ZIP_cod  familia  gasto_tarjeta  \
# 0   1         0    25            1       49    91107        4            1.6
# 1   2         0    45           19       34    90089        3            1.5
# 2   3         0    39           15       11    94720        1            1.0
# 3   4         0    35            9      100    94112        1            2.7
# 4   5         0    35            8       45    91330        4            1.0
#
#    educacion  hipoteca  valores  certificado  Online  CreditCard
# 0          1         0        1            0       0           0
# 1          1         0        1            0       0           0
# 2          1         0        0            0       0           0
# 3          2         0        0            0       0           0
# 4          2         0        0            0       0           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             5000 non-null   int64
#  1   prestamo       5000 non-null   int64
#  2   edad           5000 non-null   int64
#  3   experiencia    5000 non-null   int64
#  4   ingreso        5000 non-null   int64
#  5   ZIP_cod        5000 non-null   int64
#  6   familia        5000 non-null   int64
#  7   gasto_tarjeta  5000 non-null   float64
#  8   educacion      5000 non-null   int64
#  9   hipoteca       5000 non-null   int64
#  10  valores        5000 non-null   int64
#  11  certificado    5000 non-null   int64
#  12  Online         5000 non-null   int64
#  13  CreditCard     5000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 547.0 KB

# %%
df.describe()
# Out:
#                 ID     prestamo         edad  experiencia      ingreso  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2500.500000     0.096000    45.338400    20.104600    73.774200
# std    1443.520003     0.294621    11.463166    11.467954    46.033729
# min       1.000000     0.000000    23.000000    -3.000000     8.000000
# 25%    1250.750000     0.000000    35.000000    10.000000    39.000000
# 50%    2500.500000     0.000000    45.000000    20.000000    64.000000
# 75%    3750.250000     0.000000    55.000000    30.000000    98.000000
# max    5000.000000     1.000000    67.000000    43.000000   224.000000
#
#             ZIP_cod      familia  gasto_tarjeta    educacion     hipoteca  \
# count   5000.000000  5000.000000    5000.000000  5000.000000  5000.000000
# mean   93152.503000     2.396400       1.937938     1.881000    56.498800
# std     2121.852197     1.147663       1.747659     0.839869   101.713802
# ...

# %%
df.shape
# Out:
# (5000, 14)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of         ID  prestamo  edad  experiencia  ingreso  ZIP_cod  familia  \
# 0        1         0    25            1       49    91107        4
# 1        2         0    45           19       34    90089        3
# 2        3         0    39           15       11    94720        1
# 3        4         0    35            9      100    94112        1
# 4        5         0    35            8       45    91330        4
# ...    ...       ...   ...          ...      ...      ...      ...
# 4995  4996         0    29            3       40    92697        1
# 4996  4997         0    30            4       15    92037        4
# 4997  4998         0    63           39       24    93023        2
# 4998  4999         0    65           40       49    90034        3
# 4999  5000         0    28            4       83    92612        3
#
#       gasto_tarjeta  educacion  hipoteca  valores  certificado  Online  \
# ...

# %%
sns.lineplot(x="edad", y="experiencia", data=df).set_title("Relación entre experiencia y edad")
# Out:
# Text(0.5, 1.0, 'Relación entre experiencia y edad')

# %%
df.columns.to_list()
# Out:
# ['ID',
#  'prestamo',
#  'edad',
#  'experiencia',
#  'ingreso',
#  'ZIP_cod',
#  'familia',
#  'gasto_tarjeta',
#  'educacion',
#  'hipoteca',
#  'valores',
#  'certificado',
#  'Online',
#  'CreditCard']

# %%
sns.lineplot(x="edad",y="educacion", data=df).set_title("Relación entre edad y el nivel de estudios")
# Out:
# Text(0.5, 1.0, 'Relación entre edad y el nivel de estudios')

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.set(font_scale=1.0)
sns.countplot(x="edad",data=df).set_title("Cantidad de edades")
# Out:
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Text(0.5, 1.0, 'Cantidad de edades')

# %%
df.nunique()
# Out:
# ID               5000
# prestamo            2
# edad               45
# experiencia        47
# ingreso           162
# ZIP_cod           467
# familia             4
# gasto_tarjeta     108
# educacion           3
# hipoteca          347
# valores             2
# certificado         2
# Online              2
# CreditCard          2
# dtype: int64

# %%
sns.boxenplot(x="experiencia", y="edad",data=df).set_title("Diagrama de Caja y Bigote de los experiencia de los clientes")
# Se puede observar que los datos tienen números negativos para las edades más bajas del dataset
# Out:
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Text(0.5, 1.0, 'Diagrama de Caja y Bigote de los prestamos de los clientes')

# %%
ax = sns.countplot(x="familia", 
                   data=df, 
                   color="darkred").set_title("Cantidad de miembros de familia de cada cliente")

plt.ylabel("Cantidad total")
plt.xlabel("Cantidad de Integrantes")

plt.show()
# Out:
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
df.isna().sum()
# Out:
# ID               0
# prestamo         0
# edad             0
# experiencia      0
# ingreso          0
# ZIP_cod          0
# familia          0
# gasto_tarjeta    0
# educacion        0
# hipoteca         0
# valores          0
# certificado      0
# Online           0
# CreditCard       0
# dtype: int64

# %%
df = df.rename(columns={"prestamo": "Loan",
                            "edad": "Age",
                            "experiencia": "Experience",
                            "ingreso": "Income",
                            "familia": "Family",
                            "gasto_tarjeta": "Card_expenses",
                            "educacion": "Education",
                            "hipoteca": "Mortgage",
                            "valores": "Values",
                            "certificado": "Certificate"})

# %%
df
# Los headers fueron retitulados exitosamente
# Out:
#         ID  Loan  Age  Experience  Income  ZIP_cod  Family  Card_expenses  \
# 0        1     0   25           1      49    91107       4            1.6
# 1        2     0   45          19      34    90089       3            1.5
# 2        3     0   39          15      11    94720       1            1.0
# 3        4     0   35           9     100    94112       1            2.7
# 4        5     0   35           8      45    91330       4            1.0
# ...    ...   ...  ...         ...     ...      ...     ...            ...
# 4995  4996     0   29           3      40    92697       1            1.9
# 4996  4997     0   30           4      15    92037       4            0.4
# 4997  4998     0   63          39      24    93023       2            0.3
# 4998  4999     0   65          40      49    90034       3            0.5
# 4999  5000     0   28           4      83    92612       3            0.8
#
#       Education  Mortgage  Values  Certificate  Online  CreditCard
# ...

# %%
sns.histplot(data=df, y="Mortgage",hue="Education",multiple="stack").set_title("Distribución de la hipoteca según nivel de educación")
# Out:
# Text(0.5, 1.0, 'Distribución de la hipoteca según nivel de educación')

# %%
sns.jointplot(data=df,x="Education",y="Mortgage",hue="Card_expenses")

# %%
train = pd.read_csv("E:/Repo GitHub/Data Analysis/train.csv")

# %%
train
# Out:
#               date  store  item  sales
# 0       2013-01-01      1     1     13
# 1       2013-01-02      1     1     11
# 2       2013-01-03      1     1     14
# 3       2013-01-04      1     1     13
# 4       2013-01-05      1     1     10
# ...            ...    ...   ...    ...
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82
#
# [913000 rows x 4 columns]

# %%
train.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %%
daily_sales = train.groupby("date", as_index=False)["sales"].sum()
store_daily_sales = train.groupby(["store", "date"], as_index=False)["sales"].sum()
item_daily_sales = train.groupby(["item", "date"], as_index=False)["sales"].sum()

# %%
print(daily_sales)
print(store_daily_sales)
print(item_daily_sales)
# Out:
#             date  sales
# 0     2013-01-01  13696
# 1     2013-01-02  13678
# 2     2013-01-03  14488
# 3     2013-01-04  15677
# 4     2013-01-05  16237
# ...          ...    ...
# 1821  2017-12-27  20378
# 1822  2017-12-28  21885
# 1823  2017-12-29  23535
# 1824  2017-12-30  24988
# 1825  2017-12-31  26420
#
# [1826 rows x 2 columns]
#        store        date  sales
# 0          1  2013-01-01   1316
# 1          1  2013-01-02   1264
# 2          1  2013-01-03   1305
# 3          1  2013-01-04   1452
# 4          1  2013-01-05   1499
# ...      ...         ...    ...
# 18255     10  2017-12-27   2221
# 18256     10  2017-12-28   2429
# 18257     10  2017-12-29   2687
# 18258     10  2017-12-30   2742
# 18259     10  2017-12-31   2939
#
# [18260 rows x 3 columns]
#        item        date  sales
# 0         1  2013-01-01    133
# 1         1  2013-01-02     99
# 2         1  2013-01-03    127
# 3         1  2013-01-04    145
# 4         1  2013-01-05    149
# ...

# %%
sns.lineplot(data=daily_sales, y="sales",x="date")
# Out:
# <Axes: xlabel='date', ylabel='sales'>

# %%
train.dtypes
# Out:
# date     object
# store     int64
# item      int64
# sales     int64
# dtype: object

# %%
train["date"] = pd.to_datetime(train["date"])

# %%
train.dtypes
# Out:
# date     datetime64[ns]
# store             int64
# item              int64
# sales             int64
# dtype: object

# %%
year_sales = train.groupby(train.date.dt.year)["sales"].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 year_sales = train.groupby(train.date.dt.year)["sales"].sum()
#
# File e:\Repo GitHub\Data Analysis\.venv\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# File e:\Repo GitHub\Data Analysis\.venv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
print(year_sales)
# Out:
# date
# 2013     7941243
# 2014     9135482
# 2015     9536887
# 2016    10357160
# 2017    10733740
# Name: sales, dtype: int64

# %%
year_sales.describe
# Out:
# <bound method NDFrame.describe of date
# 2013     7941243
# 2014     9135482
# 2015     9536887
# 2016    10357160
# 2017    10733740
# Name: sales, dtype: int64>

# %%
year_sales = year_sales.reset_index()

# %%
print(year_sales)
# Out:
#    date     sales
# 0  2013   7941243
# 1  2014   9135482
# 2  2015   9536887
# 3  2016  10357160
# 4  2017  10733740

# %%
sns.lineplot(x="date",y="sales", data=year_sales).set_title("Evolución anual de las ventas")
plt.ticklabel_format(style="plain")
plt.xlabel("Fechas")
plt.ylabel("Ventas")

# I don't know how this even works, but it does what I want it to do. So I don't mind.
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(["{:,.0f}".format(x) for x in current_values])
# Out:
# C:\Users\phyrx\AppData\Local\Temp\ipykernel_11928\3995034452.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(["{:,.0f}".format(x) for x in current_values])
# [Text(0, 7500000.0, '7,500,000'),
#  Text(0, 8000000.0, '8,000,000'),
#  Text(0, 8500000.0, '8,500,000'),
#  Text(0, 9000000.0, '9,000,000'),
#  Text(0, 9500000.0, '9,500,000'),
#  Text(0, 10000000.0, '10,000,000'),
#  Text(0, 10500000.0, '10,500,000'),
#  Text(0, 11000000.0, '11,000,000')]

# %%
month_sales = train.groupby(train.date.dt.month)["sales"].sum()

# %%
print(month_sales)
# Out:
# date
# 1     2753149
# 2     2776177
# 3     3666182
# 4     4136467
# 5     4582437
# 6     4726911
# 7     5192393
# 8     4580655
# 9     4130457
# 10    3967520
# 11    4141356
# 12    3050808
# Name: sales, dtype: int64

# %%
month_sales = month_sales.reset_index()

# %%
print(month_sales)
# Out:
#     date    sales
# 0      1  2753149
# 1      2  2776177
# 2      3  3666182
# 3      4  4136467
# 4      5  4582437
# 5      6  4726911
# 6      7  5192393
# 7      8  4580655
# 8      9  4130457
# 9     10  3967520
# 10    11  4141356
# 11    12  3050808

# %%
sns.lineplot(x="date",y="sales", data=month_sales).set_title("Evolución mensual de las ventas")
plt.ticklabel_format(style="plain")
plt.xlabel("Mes")
plt.ylabel("Ventas")

# I don't know how this even works, but it does what I want it to do. So I don't mind.
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(["{:,.0f}".format(x) for x in current_values])
# Out:
# C:\Users\phyrx\AppData\Local\Temp\ipykernel_14300\3481008060.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(["{:,.0f}".format(x) for x in current_values])
# [Text(0, 2500000.0, '2,500,000'),
#  Text(0, 3000000.0, '3,000,000'),
#  Text(0, 3500000.0, '3,500,000'),
#  Text(0, 4000000.0, '4,000,000'),
#  Text(0, 4500000.0, '4,500,000'),
#  Text(0, 5000000.0, '5,000,000'),
#  Text(0, 5500000.0, '5,500,000')]

# %%
train.loc[(train["store"]==1) & (train["item"]==1)].plot(x="date", y="sales", figsize=(8,6)).set_title("Evolución del item 1 en la tienda 1")
plt.xlabel("Año")
plt.ylabel("Ventas")
plt.show()

# %%
daily_sales = train.groupby('date', as_index=False)['sales'].sum()
store_daily_sales = train.groupby(['store', 'date'], as_index=False)['sales'].sum()
item_daily_sales = train.groupby(['item', 'date'], as_index=False)['sales'].sum()

# %%
store_colors = {
    1: ("#9e0142"),
    2: ("#d53e4f"),
    3: ("#f46d43"),
    4: ("#fdae61"),
    5: ("#fee08b"),
    6: ("#e6f598"),
    7: ("#abdda4"),
    8: ("#66c2a5"),
    9: ("#3288bd"),
    10: ("#5e4fa2")
}

fig, store_plot = plt.subplots()
for store, color in store_colors.items():
    store_data = store_daily_sales[store_daily_sales["store"] == store]
    store_plot.plot(store_data["date"], store_data["sales"], label=f"Store {store}", color=color)

store_plot.set_xlabel("Año")
store_plot.set_ylabel("Ventas")
store_plot.set_title("Comparación temporal de las ventas, por tienda")
store_plot.legend(bbox_to_anchor=(1.0, 1.0))

plt.show()
